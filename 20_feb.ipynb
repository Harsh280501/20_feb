# %% [markdown]
# Q1. Explain GET and POST methods.

# %% [markdown]
# GET
#
# Get method is mainly used at the client (Browser) side to send a request to a specified server to get certain data or resources. Using this method the server should only let us receive the data and not change its state.
#
# POST
#
# Post method is mainly used at the client (Browser) side to send data to a Specified server in order to create or rewrite a particular resource/data. This data sent to the server is stored in the request body of the HTTP request.

# %% [markdown]
# Q2. Why is request used in Flask?

# %% [markdown]
# Request is used in flask in order to get the data from certain web pages and on them we can perform operations or the logic that binds the client with server

# %% [markdown]
# Q3. Why is redirect() used in Flask?

# %% [markdown]
# A redirect is used in the Flask class to send the user to a particular URL with the status code. conversely, this status code additionally identifies the issue. When we access a website, our browser sends a request to the server, and the server replies with what is known as the HTTP status code, which is a three-digit number.

# %% [markdown]
# Q4. What are templates in Flask? Why is the render_template() function used?

# %% [markdown]
# Templates are the html file which gives an interactive web page and components which can be interected with the help of flask framework.
#
# render_template() function is used to render the html file we want to dislay or show

# %% [markdown]
# Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %% [markdown]
# ![image.png](attachment:bb3f5158-2b9f-49eb-90be-373508e11387.png)
